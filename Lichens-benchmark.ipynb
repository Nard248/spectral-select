# %%
from scripts.utils.pipeline_notebook_helpers import (load_data_and_ground_truth, run_baseline_classification, run_wavelength_selection_experiment)

data, gt, rois = load_data_and_ground_truth(
    'Data/processed/LichensProcessed',
    'Data/processed/Lichens_2/labeled_lichens.png'
)
# Out:
# Loading from: Data/processed/LichensProcessed
#   Using pickle: data_cutoff_60nm_exposure_max_power_min.pkl
# Data loaded:
#   Excitations: 8
#   Total bands: 187
#   Spatial: 256 x 348
#
# Ground truth loaded:
#   Classes: 5
#     Class 0: 4,773 pixels (5.4%)
#     Class 1: 9,242 pixels (10.4%)
#     Class 2: 3,558 pixels (4.0%)
#     Class 3: 425 pixels (0.5%)
#     Class 4: 4,518 pixels (5.1%)
#
# Auto-detected 5 ROI regions

# %%
baseline = run_baseline_classification(data, gt, rois)
# Out:
# ...
# BASELINE: Full Data Classification
# ...
#   Training: 4057 samples, 5 classes
#   Accuracy: 0.7365, F1: 0.7243
