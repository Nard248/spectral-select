# %% [markdown]
# # Data Loading and Processing
#
# This notebook demonstrates how to load and process raw hyperspectral data for use with the `spectral_select` library.
#
# **What you'll learn:**
# - Load raw `.im3` hyperspectral files
# - Apply spectral cutoffs (Rayleigh and second-order)
# - Normalize by exposure time and laser power
# - Save processed data to pickle format
# - Load processed data with `SpectraData`

# %% [markdown]
# ## 1. Setup
#
# Import the data processing utilities from the `scripts` module:

# %%
import sys
from pathlib import Path

# Add scripts to path (if running from notebooks/examples)
project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root / "scripts"))

from data_processing import HyperspectralProcessor, HyperspectralDataLoader
from spectral_select import SpectraData

# %% [markdown]
# ## 2. Configure Paths
#
# Set up paths to your raw data and metadata files:

# %%
# === UPDATE THESE PATHS FOR YOUR DATA ===

# Directory containing .im3 files (named by excitation wavelength, e.g., "365.0.im3")
DATA_DIR = project_root / "Data" / "Raw" / "Lichens_2"

# Excel file with exposure times (columns: Excitation, Exposure)
METADATA_PATH = DATA_DIR / "metadata.xlsx"

# Excel file with laser power measurements (columns: Excitation Wavelength (nm), Average Power (W))
LASER_POWER_PATH = DATA_DIR / "TLS Scans" / "average_power.xlsx"

# Output directory for processed data
OUTPUT_DIR = project_root / "Data" / "processed" / "LichensProcessed"

# Spectral cutoff offset in nm
CUTOFF_OFFSET = 60

print(f"Data directory: {DATA_DIR}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Data directory: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2
# Output directory: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed

# %% [markdown]
# ## 3. Method A: Full Pipeline Processing
#
# Use `HyperspectralProcessor` for a complete processing pipeline including:
# - Spectral cutoff (Rayleigh + second-order)
# - Exposure time normalization
# - Laser power normalization

# %%
# Create processor
processor = HyperspectralProcessor(
    data_path=str(DATA_DIR),
    metadata_path=str(METADATA_PATH),
    laser_power_excel=str(LASER_POWER_PATH),
    cutoff_offset=CUTOFF_OFFSET,
    verbose=True,
)

# Run full pipeline
output_files = processor.process_full_pipeline(
    output_dir=str(OUTPUT_DIR),
    exposure_reference="max",  # Normalize to max exposure time
    power_reference="min",     # Normalize to min laser power
    create_parquet=False,
    preserve_full_data=True,
)

print("\nGenerated files:")
for name, path in output_files.items():
    print(f"  {name}: {path}")
# Out:
# Initializing ImageJ (Fiji)...
# WARNING: package sun.awt.X11 not in java.desktop
# [ERROR] Cannot create plugin: org.scijava.plugins.scripting.javascript.JavaScriptScriptLanguage
# === Step 1: Loading data with dual cutoff (offset: 60nm) ===
# Loading 310.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/310.im3
# Operating in headless mode - the original ImageJ will have limited functionality.
# Loading 325.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/325.im3
# Loading 340.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/340.im3
# Loading 365.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/365.im3
# Loading 385.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/385.im3
# Loading 400.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/400.im3
# Loading 415.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/415.im3
# Loading 430.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/430.im3
# Processing data with cutoff offset: 60nm...
# Applied dual cutoff for excitation 310.0nm
# Removed wavelengths below 370.0nm (Rayleigh cutoff)
# Removed wavelengths between 560.0nm and 680.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 18)
# Applied dual cutoff for excitation 325.0nm
# Removed wavelengths below 385.0nm (Rayleigh cutoff)
# Removed wavelengths between 590.0nm and 710.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 18)
# Applied dual cutoff for excitation 340.0nm
# Removed wavelengths below 400.0nm (Rayleigh cutoff)
# Removed wavelengths between 620.0nm and 740.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 20)
# Applied dual cutoff for excitation 365.0nm
# Removed wavelengths below 425.0nm (Rayleigh cutoff)
# Removed wavelengths between 670.0nm and 790.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 24)
# Applied dual cutoff for excitation 385.0nm
# Removed wavelengths below 445.0nm (Rayleigh cutoff)
# Removed wavelengths between 710.0nm and 830.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 26)
# Applied dual cutoff for excitation 400.0nm
# Removed wavelengths below 460.0nm (Rayleigh cutoff)
# Removed wavelengths between 740.0nm and 860.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
# Applied dual cutoff for excitation 415.0nm
# Removed wavelengths below 475.0nm (Rayleigh cutoff)
# Removed wavelengths between 770.0nm and 890.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
# Applied dual cutoff for excitation 430.0nm
# Removed wavelengths below 490.0nm (Rayleigh cutoff)
# Removed wavelengths between 800.0nm and 920.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
# Data with dual cutoff saved to: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_dual_cutoff_60nm.pkl
#
# === Step 2: Normalizing by exposure time (max reference) ===
# Normalizing hyperspectral data by exposure time using max reference...
# Found exposure times for 8 excitation wavelengths
# Using maximum exposure time as reference: 5432.9
# Exposure normalization plot saved to: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max.exposure_normalization.png
# Normalizing data cubes by exposure time...
#   Normalized excitation 310.0nm (Exposure: 5432.9, Factor: 1.0000)
#   Normalized excitation 325.0nm (Exposure: 924.52, Factor: 5.8765)
#   Normalized excitation 340.0nm (Exposure: 656.47, Factor: 8.2759)
#   Normalized excitation 365.0nm (Exposure: 97.79, Factor: 55.5568)
#   Normalized excitation 385.0nm (Exposure: 48.22, Factor: 112.6690)
#   Normalized excitation 400.0nm (Exposure: 12.5, Factor: 434.6320)
#   Normalized excitation 415.0nm (Exposure: 35.0, Factor: 155.2257)
#   Normalized excitation 430.0nm (Exposure: 35.0, Factor: 155.2257)
# Exposure normalized data saved to /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max.pkl
#
# === Step 3: Normalizing by laser power (min reference) ===
# Read laser powers for 8 excitation wavelengths from /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/TLS Scans/average_power.xlsx
# Normalizing hyperspectral data by laser power using min reference...
# Using minimum laser power as reference: 0.00030540 W
# Laser power normalization plot saved to: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max_power_min.power_normalization.png
# Normalizing data cubes by laser power...
#   Normalized excitation 310.0nm (Power: 0.00041610 W, Factor: 0.7340)
#   Normalized excitation 325.0nm (Power: 0.00030540 W, Factor: 1.0000)
#   Normalized excitation 340.0nm (Power: 0.00090300 W, Factor: 0.3382)
#   Normalized excitation 365.0nm (Power: 0.01025000 W, Factor: 0.0298)
#   Normalized excitation 385.0nm (Power: 0.01531000 W, Factor: 0.0199)
#   Normalized excitation 400.0nm (Power: 0.00426500 W, Factor: 0.0716)
#   Normalized excitation 415.0nm (Power: 0.00767000 W, Factor: 0.0398)
#   Normalized excitation 430.0nm (Power: 0.00449100 W, Factor: 0.0680)
# Laser power normalized data saved to /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max_power_min.pkl
#
# === Processing complete! ===
# 1. Data with dual cutoff: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_dual_cutoff_60nm.pkl
# 2. Data normalized by exposure time (max reference): /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max.pkl
# 3. Data normalized by both exposure and laser power: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max_power_min.pkl
#
# Generated files:
#   cutoff: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_dual_cutoff_60nm.pkl
#   exposure_normalized: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max.pkl
#   power_normalized: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max_power_min.pkl

# %%
# View data summary
processor.print_summary()
# Out:
# === Hyperspectral Processing Summary ===
#
# Data Status:
#   Raw data loaded: Yes
#   Cutoff applied: Yes
#   Exposure normalized: Yes
#   Power normalized: Yes
#
# Normalization Information:
#   Exposure times: 8 excitation wavelengths
#   Exposure range: 12.50 - 5432.90
#   Laser powers: 8 excitation wavelengths
#   Laser power range: 0.00030540W - 0.01531000W
#
# Output Files:
#   Cutoff data: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_dual_cutoff_60nm.pkl
#   Exposure normalized: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max.pkl
#   Power normalized: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_cutoff_60nm_exposure_max_power_min.pkl
#
# Cutoff Details:
#   Rayleigh cutoff offset: 60nm
#   Second order cutoff offset: 60nm
#
#   Excitation 310.0nm:
#     Data shape: (256, 348, 18)
#     Emission range: 420.0nm - 720.0nm
#     Number of emission bands: 18
#
#   Excitation 325.0nm:
#     Data shape: (256, 348, 18)
#     Emission range: 420.0nm - 720.0nm
#     Number of emission bands: 18
#
#   Excitation 340.0nm:
#     Data shape: (256, 348, 20)
#     Emission range: 420.0nm - 610.0nm
#     Number of emission bands: 20
#
#   Excitation 365.0nm:
#     Data shape: (256, 348, 24)
#     Emission range: 430.0nm - 660.0nm
#     Number of emission bands: 24
#
#   Excitation 385.0nm:
#     Data shape: (256, 348, 26)
#     Emission range: 450.0nm - 700.0nm
#     Number of emission bands: 26
#
#   Excitation 400.0nm:
#     Data shape: (256, 348, 27)
#     Emission range: 460.0nm - 720.0nm
#     Number of emission bands: 27
#
#   Excitation 415.0nm:
#     Data shape: (256, 348, 27)
#     Emission range: 475.0nm - 735.0nm
#     Number of emission bands: 27
#
#   Excitation 430.0nm:
#     Data shape: (256, 348, 27)
#     Emission range: 490.0nm - 750.0nm
#     Number of emission bands: 27

# %% [markdown]
# ## 4. Method B: Step-by-Step Loading
#
# For more control, use `HyperspectralDataLoader` to load and process data step by step:

# %%
# Create loader (requires ImageJ/Fiji for .im3 files)
loader = HyperspectralDataLoader(
    data_path=str(DATA_DIR),
    metadata_path=str(METADATA_PATH),
    cutoff_offset=CUTOFF_OFFSET,
    use_fiji=True,
    verbose=True,
)

# Load data with spectral cutoff
data = loader.load_data(apply_cutoff=True, pattern="*.im3")

print(f"\nLoaded {len(loader.excitation_wavelengths)} excitation wavelengths:")
print(loader.excitation_wavelengths)
# Out:
# Initializing ImageJ (Fiji)...
# Loading 310.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/310.im3
# Operating in headless mode - the original ImageJ will have limited functionality.
# Loading 325.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/325.im3
# Loading 340.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/340.im3
# Loading 365.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/365.im3
# Loading 385.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/385.im3
# Loading 400.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/400.im3
# Loading 415.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/415.im3
# Loading 430.im3 ...
# IM3Reader initializing /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/Raw/Lichens_2/430.im3
# Processing data with cutoff offset: 60nm...
# Applied dual cutoff for excitation 310.0nm
# Removed wavelengths below 370.0nm (Rayleigh cutoff)
# Removed wavelengths between 560.0nm and 680.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 18)
# Applied dual cutoff for excitation 325.0nm
# Removed wavelengths below 385.0nm (Rayleigh cutoff)
# Removed wavelengths between 590.0nm and 710.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 18)
# Applied dual cutoff for excitation 340.0nm
# Removed wavelengths below 400.0nm (Rayleigh cutoff)
# Removed wavelengths between 620.0nm and 740.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 20)
# Applied dual cutoff for excitation 365.0nm
# Removed wavelengths below 425.0nm (Rayleigh cutoff)
# Removed wavelengths between 670.0nm and 790.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 24)
# Applied dual cutoff for excitation 385.0nm
# Removed wavelengths below 445.0nm (Rayleigh cutoff)
# Removed wavelengths between 710.0nm and 830.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 26)
# Applied dual cutoff for excitation 400.0nm
# Removed wavelengths below 460.0nm (Rayleigh cutoff)
# Removed wavelengths between 740.0nm and 860.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
# Applied dual cutoff for excitation 415.0nm
# Removed wavelengths below 475.0nm (Rayleigh cutoff)
# Removed wavelengths between 770.0nm and 890.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
# Applied dual cutoff for excitation 430.0nm
# Removed wavelengths below 490.0nm (Rayleigh cutoff)
# Removed wavelengths between 800.0nm and 920.0nm (second-order cutoff)
# Original data shape: (256, 348, 31), filtered shape: (256, 348, 27)
#
# Loaded 8 excitation wavelengths:
# [310.0, 325.0, 340.0, 365.0, 385.0, 400.0, 415.0, 430.0]

# %%
# Access data for a specific excitation
excitation = loader.excitation_wavelengths[0]
cube, wavelengths = loader.get_cube(excitation, processed=True)

print(f"\nData for excitation {excitation}nm:")
print(f"  Cube shape: {cube.shape} (height, width, bands)")
print(f"  Emission wavelengths: {wavelengths[:5]}... ({len(wavelengths)} total)")
# Out:
# Data for excitation 310.0nm:
#   Cube shape: (256, 348, 18) (height, width, bands)
#   Emission wavelengths: [420.0, 430.0, 440.0, 450.0, 460.0]... (18 total)

# %%
# Visualize the cutoff effect
loader.visualize_cutoff(excitation)

# %%
# Save to pickle
output_file = OUTPUT_DIR / "data_manual_processing.pkl"
loader.save_to_pkl(str(output_file))
print(f"Saved to: {output_file}")
# Out:
# Data saved to /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_manual_processing.pkl
# Saved to: /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/Data/processed/LichensProcessed/data_manual_processing.pkl

# %% [markdown]
# ## 5. Load Processed Data with SpectraData
#
# Once data is saved to pickle, load it with `SpectraData.from_pickle()`:

# %%
# Load the processed pickle file
# Use the file generated by the processor or loader
pkl_path = OUTPUT_DIR / f"data_cutoff_{CUTOFF_OFFSET}nm_exposure_max_power_min.pkl"

data = SpectraData.from_pickle(pkl_path)

print(f"Sample: {data.sample_name}")
print(f"Spatial shape: {data.spatial_shape}")
print(f"Number of excitations: {data.n_excitations}")
print(f"Excitation wavelengths: {data.excitation_wavelengths}")
# Out:
# Sample: data_cutoff_60nm_exposure_max_power_min
# Spatial shape: (256, 348)
# Number of excitations: 8
# Excitation wavelengths: [310.0, 325.0, 340.0, 365.0, 385.0, 400.0, 415.0, 430.0]

# %%
# Access per-excitation data
for ex_nm in data.excitation_wavelengths:
    ex_data = data.get_excitation(ex_nm)
    print(f"Ex {ex_nm:.0f}nm: {ex_data.n_bands} bands, shape {ex_data.shape}")
# Out:
# Ex 310nm: 18 bands, shape (256, 348, 18)
# Ex 325nm: 18 bands, shape (256, 348, 18)
# Ex 340nm: 20 bands, shape (256, 348, 20)
# Ex 365nm: 24 bands, shape (256, 348, 24)
# Ex 385nm: 26 bands, shape (256, 348, 26)
# Ex 400nm: 27 bands, shape (256, 348, 27)
# Ex 415nm: 27 bands, shape (256, 348, 27)
# Ex 430nm: 27 bands, shape (256, 348, 27)

# %% [markdown]
# ## 6. Visualize Spectra
#
# Use the loader's visualization utilities to explore the data:

# %%
# Plot mean emission spectrum for all excitations
loader.visualize_spectrum(excitation=None, processed=True)

# %%
# Visualize a single band image
loader.visualize_image(excitation=365.0, emission_wavelength=500.0)

# %%
# Create false color visualization
loader.visualize_false_color(excitation=365.0, method='pca')
# Out:
# /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/.venv/lib/python3.11/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: divide by zero encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/.venv/lib/python3.11/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: overflow encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/narekmeloyan/PycharmProjects/4D-Hyperspectral-Unsupervised-Clustering/.venv/lib/python3.11/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: invalid value encountered in matmul
#   X_transformed = X @ self.components_.T

# %% [markdown]
# ## Expected File Structure
#
# Your raw data directory should look like this:
#
# ```
# Data/Raw/YourSample/
# ├── 310.0.im3        # Named by excitation wavelength
# ├── 325.0.im3
# ├── 340.0.im3
# ├── 365.0.im3
# ├── 385.0.im3
# ├── 400.0.im3
# ├── 415.0.im3
# ├── 430.0.im3
# ├── metadata.xlsx    # Columns: Excitation, Exposure
# └── TLS Scans/
#     └── average_power.xlsx  # Laser power measurements
# ```
#
# ## Pickle File Format
#
# The saved pickle file contains:
#
# ```python
# {
#     'data': {
#         '310.0': {
#             'cube': np.ndarray,       # (H, W, bands)
#             'wavelengths': [420.0, 430.0, ...],
#             'excitation': 310.0,
#             'raw': {...},
#             'exposure_normalization_factor': float,
#             'laser_power_normalization_factor': float,
#         },
#         '325.0': {...},
#         ...
#     },
#     'excitation_wavelengths': [310.0, 325.0, ...],
#     'metadata': {...},
#     'cutoff_offset': 40,
# }
# ```

# %% [markdown]
# ## Summary
#
# In this notebook, you learned how to:
#
# 1. **Full pipeline** with `HyperspectralProcessor.process_full_pipeline()`
# 2. **Step-by-step** with `HyperspectralDataLoader.load_data()`
# 3. **Save** processed data with `loader.save_to_pkl()`
# 4. **Load** with `SpectraData.from_pickle()`
# 5. **Visualize** spectra and images
#
# **Next steps:**
# - See `01_quickstart.ipynb` for running wavelength selection analysis
# - See `02_validation.ipynb` for validating with ground truth
